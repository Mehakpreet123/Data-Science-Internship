# %%
import pandas as pd

# %% [markdown]
# ADDING NEW COLUMNS TO THE EXISTING DATAFRAME

# %%
# using insert
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}

# Convert the dictionary into DataFrame
df = pd.DataFrame(data)

# Using DataFrame.insert() to add a column
df.insert(2, "Age", [21, 23, 24, 21], True)  # (index,col,values,allow_duplicates)

# Observe the result
print(df)
print("--------------------------------------------------------")
 
# using assign --- it returns new df 
new_df=df.assign(State=["Punjab","Delhi","Haryana","Chandigarh"])
display(new_df)

print("----------------------------------------------------------")
# basic method
df["Grades"]=[90,89,67,85]
print(df)
print("----------------------------------------------------------")

# using loc
address = ["Delhi", "Bangalore", "Chennai", "Patna"]
df.loc[:, "Address"] = address
print(df)
print("----------------------------------------------------------")
# adding multiple columns at once
Salary = [22, 25, 23, 24]
Location = ['NCT', 'Karnataka', 'Tamil Nadu', 'Bihar']

# Add multiple columns using dictionary assignment
new_data = {'Salary': Salary, 'Location': Location }
df2 = df.assign(**new_data)
display(df2)
# Out:
#      Name  Height  Age Qualification
# 0     Jai     5.1   21           Msc
# 1  Princi     6.2   23            MA
# 2  Gaurav     5.1   24           Msc
# 3    Anuj     5.2   21           Msc
# --------------------------------------------------------
#      Name  Height  Age Qualification       State
# 0     Jai     5.1   21           Msc      Punjab
# 1  Princi     6.2   23            MA       Delhi
# 2  Gaurav     5.1   24           Msc     Haryana
# 3    Anuj     5.2   21           Msc  Chandigarh
# ----------------------------------------------------------
#      Name  Height  Age Qualification  Grades
# 0     Jai     5.1   21           Msc      90
# 1  Princi     6.2   23            MA      89
# 2  Gaurav     5.1   24           Msc      67
# 3    Anuj     5.2   21           Msc      85
# ----------------------------------------------------------
#      Name  Height  Age Qualification  Grades    Address
# 0     Jai     5.1   21           Msc      90      Delhi
# ...

# %%
# data = pd.read_csv("iris.csv", index_col="Name") index_col to make column as index

# %%
# to drop rows
df.drop(0,inplace=True)  #([labels],axis,inplace)  axis=0 by default
display(df)

# %%
# to drop columns
df.drop(["Salary","Location"],axis=1,inplace=True)
display(df)

# %%
display(df)
# df.index=[1,2,3,4] to add index explicitly
# Out:
#      Name  Height  Age Qualification  Grades    Address
# 1  Princi     6.2   23            MA      89  Bangalore
# 2  Gaurav     5.1   24           Msc      67    Chennai
# 3    Anuj     5.2   21           Msc      85      Patna

# %% [markdown]
# Syntax: DataFrame.truncate(before=None, after=None, axis=None, copy=True)
#
# Parameter :
# before : Truncate all rows before this index value.
# after : Truncate all rows after this index value.
# axis : Axis to truncate. Truncates the index (rows) by default.
# copy : Return a copy of the truncated section.
#
# Returns : The truncated Series or DataFrame.

# %%
df = pd.DataFrame({'Weight':[45, 88, 56, 15, 71], 
                   'Name':['Sam', 'Andrea', 'Alex', 'Robin', 'Kia'], 
                   'Age':[14, 25, 55, 8, 21]}) 
  
index_ = [5,6,7,8,9]
  
df.index = index_ 
display(df)

# truncate -- to truncate the df before and after some index
new_df=df.truncate(before=6,after=8)
print(new_df)
# Out:
#    Weight    Name  Age
# 5      45     Sam   14
# 6      88  Andrea   25
# 7      56    Alex   55
# 8      15   Robin    8
# 9      71     Kia   21
#    Weight    Name  Age
# 6      88  Andrea   25
# 7      56    Alex   55
# 8      15   Robin    8

# %% [markdown]
# Syntax: Series.truncate(before=None, after=None, axis=None, copy=True)
#
# Parameter :
# before : Truncate all rows before this index value.
# after : Truncate all rows after this index value.
# axis : Axis to truncate. Truncates the index (rows) by default.
# copy : Return a copy of the truncated section.

# %% [markdown]
# ITERATING OVER ROWS

# %%
for i,j in df.iterrows():  # this function returns each index value along with a series containing the data in each row.
    print(i,j) # i for index j for row
# Out:
# 5 Weight     45
# Name      Sam
# Age        14
# Name: 5, dtype: object
# 6 Weight        88
# Name      Andrea
# Age           25
# Name: 6, dtype: object
# 7 Weight      56
# Name      Alex
# Age         55
# Name: 7, dtype: object
# 8 Weight       15
# Name      Robin
# Age           8
# Name: 8, dtype: object
# 9 Weight     71
# Name      Kia
# Age        21
# Name: 9, dtype: object

# %%
for i in df.itertuples():
    print(i)
# Out:
# Pandas(Index=5, Weight=45, Name='Sam', Age=14)
# Pandas(Index=6, Weight=88, Name='Andrea', Age=25)
# Pandas(Index=7, Weight=56, Name='Alex', Age=55)
# Pandas(Index=8, Weight=15, Name='Robin', Age=8)
# Pandas(Index=9, Weight=71, Name='Kia', Age=21)

# %% [markdown]
# ITERATING OVER COLUMNS

# %%
columns = list(df)
print(columns)
for i in columns:
    #print(i) # return column name
    #print(df[i]) #return index and col values
    print(df[i][6]) # all column values for index 6 only
print(df.columns)
# Out:
# ['Weight', 'Name', 'Age']
# 88
# Andrea
# 25
# Index(['Weight', 'Name', 'Age'], dtype='object')

# %%
df=pd.read_csv("C:/Users/HP/Downloads/employees.csv")
print(df.info())
df.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB
# None
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 385      Debra  Female  1/19/2010         8:48 AM   70492    8.895
# 952     Teresa  Female  1/22/2013         3:17 PM  113425   11.907
# 353        NaN    Male  4/22/1997         9:36 PM   65078    3.095
# ...

# %%
nan_filter=pd.isnull(df["Team"])
nan_count=pd.isnull(df["Team"]).sum()
df[nan_filter]  # to get all the rows with null values
# Out:
#       First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 10        Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 23           NaN    Male   6/14/2012         4:19 PM  125792    5.042
# 32           NaN    Male   8/21/1998         2:27 PM  122340    6.417
# 91         James     NaN   1/26/2005        11:00 PM  128771    8.309
# 109  Christopher    Male   4/22/2000        10:15 AM   37919   11.449
# 139          NaN  Female   10/3/1990         1:08 AM  132373   10.527
# 199     Jonathan    Male   7/17/2009         8:15 AM  130581   16.736
# 258      Michael    Male   1/24/2002         3:04 AM   43586   12.659
# 290       Jeremy    Male   6/14/1988         6:20 PM  129460   13.657
# 314        Bobby    Male   3/31/1996         5:40 PM  112117    6.338
# 367       Edward    Male    8/4/1989         6:06 AM   66067   10.957
# ...

# %%
filter_=pd.notnull(df["Gender"]) # this gives true for non null values
print(filter_)
filter_.sum() # 855 non null values
(df[~(filter_)])  # gives all rows where gender is nan
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN   4/22/1995         7:18 PM   64714    4.934
# 22      Joshua    NaN    3/8/2012         1:58 AM   90816   18.816
# 27       Scott    NaN   7/11/1991         6:58 PM  122367    5.218
# 31       Joyce    NaN   2/20/2005         2:40 PM   88657   12.752
# 41   Christine    NaN   6/28/2015         1:08 AM   66582   11.308
# ..         ...    ...         ...             ...     ...      ...
# 961    Antonio    NaN   6/18/1989         9:37 PM  103050    3.050
# 972     Victor    NaN   7/28/2006         2:49 PM   76381   11.159
# 985    Stephen    NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin    NaN   2/10/1991         4:58 PM   38344    3.794
# ...

# %% [markdown]
# DataFrameName.dropna(axis=0, how=’any’, thresh=None, subset=None, inplace=False)
#
# Parameters:
#
# axis: axis takes int or string value for rows/columns. Input can be 0 or 1 for Integer and ‘index’ or ‘columns’ for String.
# how: how takes string value of two kinds only (‘any’ or ‘all’). ‘any’ drops the row/column if ANY value is Null and ‘all’ drops only if ALL values are null.
# thresh: thresh takes integer value which tells minimum amount of na values to drop.
# subset: It’s an array which limits the dropping process to passed rows/columns through list. inplace: It is a boolean which makes the changes in data frame itself if True.

# %%
new_data = df["Gender"].dropna(axis=0, how='any')
print(len(new_data))
print(len(df))
# Out:
# 855
# 1000

# %% [markdown]
# DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None, **kwargs)
# value : Static, dictionary, array, series or dataframe to fill instead of NaN.
# method : Method is used if user doesn’t pass any value. Pandas have different methods like bfill, backfill, or ffill which fills the place with value in the Forward index or Previous/Back respectively.
# axis: axis takes int or string value for rows/columns. Input can be 0 or 1 for Integer and ‘index’ or ‘columns’ for String
# inplace: It is a boolean which makes the changes in data frame itself if True.
# limit : This is an integer value which specifies maximum number of consecutive forward/backward NaN value fills.
# downcast : It takes a dict which specifies what dtype to downcast to which one. Like Float64 to int64.
# **kwargs : Any other Keyword arguments

# %%
# dropping column with all null values
df.dropna(axis=1, how='all', inplace=True)

# %%
# comparing values after dropping null column
print("\nColumn number after dropping Null column\n",len(df.dtypes))
# Out:
# Column number after dropping Null column
#  8

# %%
df_filled = df.fillna({'A': 0, 'B': 1, 'C': 2})
print("\nFill NaNs with different values for each column:")
print(df_filled)

df["Team"].ffill()
df['Team'].bfill() # or df['Team'].fillna(method='bfill')
# df['Team'].fillna('No Team')  -- to fill with particular value
# df['Team'].interpolate()
# The interpolate method in pandas is primarily used for numerical data, 
# where it estimates missing values by interpolating between existing values.
# Out:
# 0                 Marketing
# 1                 Marketing
# 2                   Finance
# 3                   Finance
# 4           Client Services
#                ...
# 995            Distribution
# 996                 Finance
# 997                 Product
# 998    Business Development
# 999                   Sales
# Name: Team, Length: 1000, dtype: object

# %% [markdown]
# Syntax: DataFrame.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method=’pad’, axis=None)
#
# Parameters:
#
# to_replace : [str, regex, list, dict, Series, numeric, or None] pattern that we are trying to replace in dataframe.
# value : Value to use to fill holes (e.g. 0), alternately a dict of values specifying which value to use for each column (columns not in the dict will not be filled). Regular expressions, strings and lists or dicts of such objects are also allowed.
# inplace : If True, in place. Note: this will modify any other views on this object (e.g. a column from a DataFrame). Returns the caller if this is True.
# limit : Maximum size gap to forward or backward fill

# %%
dataframe = {
  "Array_1": [49.50, 70],
  "Array_2": [65.1, 49.50]
}
 
data = pd.DataFrame(dataframe)
 
print(data.replace(49.50, 60))
# df.replace(to_replace=["Boston Celtics", "Texas"],value="Omega Warrior")
#df[:10]
# this will replace "Boston Celtics" with "Omega Warrior"
#df.replace(to_replace="Boston Celtics",value="Omega Warrior")
# Out:
#    Array_1  Array_2
# 0     60.0     65.1
# 1     70.0     60.0

# %% [markdown]
# Syntax: DataFrame.interpolate(method=’linear’, axis=0, limit=None, inplace=False, limit_direction=’forward’, limit_area=None, downcast=None, **kwargs)
#
# Parameters :
#
# method : {‘linear’, ‘time’, ‘index’, ‘values’, ‘nearest’, ‘zero’, ‘slinear’, ‘quadratic’, ‘cubic’, ‘barycentric’, ‘krogh’, ‘polynomial’, ‘spline’, ‘piecewise_polynomial’, ‘from_derivatives’, ‘pchip’, ‘akima’}
# axis : 0 fill column-by-column and 1 fill row-by-row.
# limit : Maximum number of consecutive NaNs to fill. Must be greater than 0. l
# imit_direction : {‘forward’, ‘backward’, ‘both’}, default ‘forward’
# limit_area : None (default) no fill restriction. inside Only fill NaNs surrounded by valid values (interpolate). outside Only fill NaNs outside valid values (extrapolate). If limit is specified, consecutive NaNs will be filled in this direction.
# inplace : Update the NDFrame in place if possible.
# downcast : Downcast dtypes if possible.
# kwargs : keyword arguments to pass on to the interpolating function.

# %%
df = pd.DataFrame({"A":[12, 4, 5, None, 1], 
                   "B":[None, 2, 54, 3, None], 
                   "C":[20, 16, None, 3, 8], 
                   "D":[14, 3, None, None, 6]}) 
# to interpolate the missing values 
df.interpolate(method ='linear', limit_direction ='forward')

# %% [markdown]
# Linear Interpolation: Linear interpolation estimates missing values by connecting two known points with a straight line. It uses the formula for the line to fill in the missing values between these points.
# Forward Direction: The interpolation only considers previous and next values in a forward direction, which means it will not interpolate using values that appear after the missing value in the sequence.

# %% [markdown]
# SORTING

# %% [markdown]
# Syntax: DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, kind=’quicksort’, na_position=’last’)
#
# Note: Every parameter has some default values except the ‘by’ parameter.
#
# Parameters:
#
# by: Single/List of column names to sort Data Frame by.
# axis: 0 or ‘index’ for rows and 1 or ‘columns’ for Column.
# ascending: Boolean value which sorts Data frame in ascending order if True.
# inplace: Boolean value. Makes the changes in passed data frame itself if True.
# kind: String which can have three inputs(‘quicksort’, ‘mergesort’ or ‘heapsort’) of algorithm used to sort data frame.
# na_position: Takes two string input ‘last’ or ‘first’ to set position of Null values. Default is ‘last’.

# %%
df.sort_values("First Name" )# it is changing the index also
df.sort_values("First Name").reset_index() # to reset the index
# Out:
#      index First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 1      327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 2      440      Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 3      937      Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 4      137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..     ...        ...     ...        ...             ...     ...      ...
# 995    902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 996    925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 997    946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 998    947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 999    951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 0                True        Marketing
# ...

# %%
df.sort_values("Salary", axis=0, ascending=True,
                 inplace=True, na_position='first')
df
# df['Salary'].isnull().sum() # 0
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 576    Michael    Male  7/30/1993         5:35 PM   35013   14.879
# 238      Kevin    Male  3/25/1982         7:31 AM   35061    5.128
# 82      Steven    Male  3/30/1980         9:20 PM   35095    8.379
# 63     Matthew    Male   1/2/2013        10:33 PM   35203   18.040
# 650    Cynthia  Female   7/5/1986         1:24 AM   35381   11.749
# ..         ...     ...        ...             ...     ...      ...
# 160      Kathy  Female  3/18/2000         7:26 PM  149563   16.991
# 186        NaN  Female  2/23/2005         9:50 PM  149654    1.825
# 828    Cynthia  Female  7/12/2006         8:55 AM  149684    7.864
# 429       Rose  Female  5/28/2015         8:40 AM  149903    5.630
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
#
#     Senior Management             Team
# 576             False          Product
# 238             False            Legal
# 82               True  Client Services
# ...
